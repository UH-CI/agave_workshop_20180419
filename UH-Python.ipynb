# %% [markdown]
# In this notebook, we introduce some basic uses of the agavepy Python library for interacting with the Agave Platform science-as-a-service APIs. The examples primarily draw from the apps service, but the concepts introduced are broadly applicable to all Agave services. In subsequent notebooks, we'll take deeper dives into specific topics such as using agavepy to launch and monitor an Agave job. For more information about Agave, please see the developer site: http://agaveapi.co/

# %%
# !mkdir -p ~/agave
# %cd ~/agave
# !pip install --upgrade setvar
# !pip install agavepy
# Out:
# /Users/scleveland/AGAVE
# Requirement already up-to-date: setvar in /Users/scleveland/anaconda/envs/py36/lib/python3.6/site-packages
# You are using pip version 9.0.1, however version 10.0.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting agavepy
#   Downloading https://files.pythonhosted.org/packages/08/b2/db827a9c1183e364cf85bfc7cbb4f23c8c5a6b83cbd5ae7ab785f9fe354c/agavepy-0.7.0.tar.gz (97kB)
#     100% |████████████████████████████████| 102kB 431kB/s
# Collecting Jinja2==2.7.3 (from agavepy)
#   Downloading https://files.pythonhosted.org/packages/b0/73/eab0bca302d6d6a0b5c402f47ad1760dc9cb2dd14bbc1873ad48db258e4d/Jinja2-2.7.3.tar.gz (378kB)
#     100% |████████████████████████████████| 378kB 3.0MB/s
# Collecting backports.ssl-match-hostname>=3.4.0.2 (from agavepy)
#   Downloading https://files.pythonhosted.org/packages/76/21/2dc61178a2038a5cb35d14b61467c6ac632791ed05131dda72c20e7b9e23/backports.ssl_match_hostname-3.5.0.1.tar.gz
# Requirement already satisfied: py>=1.4.26 in /Users/scleveland/anaconda/envs/py36/lib/python3.6/site-packages (from agavepy)
# Requirement already satisfied: pytest>=2.7.0 in /Users/scleveland/anaconda/envs/py36/lib/python3.6/site-packages (from agavepy)
# Requirement already satisfied: python-dateutil>=2.4.2 in /Users/scleveland/anaconda/envs/py36/lib/python3.6/site-packages (from agavepy)
# Requirement already satisfied: requests>=2.6.0 in /Users/scleveland/anaconda/envs/py36/lib/python3.6/site-packages (from agavepy)
# Requirement already satisfied: six>=1.9.0 in /Users/scleveland/anaconda/envs/py36/lib/python3.6/site-packages (from agavepy)
# Collecting websocket-client>=0.29.0 (from agavepy)
#   Downloading https://files.pythonhosted.org/packages/9d/fb/f51a03e232e00d6c504dfe815aed090c894ba3f8d3f7fd9612f3e227bf24/websocket_client-0.47.0-py2.py3-none-any.whl (200kB)
#     100% |████████████████████████████████| 204kB 4.4MB/s
# Collecting requests_toolbelt>=0.7.1 (from agavepy)
#   Downloading https://files.pythonhosted.org/packages/97/8a/d710f792d6f6ecc089c5e55b66e66c3f2f35516a1ede5a8f54c13350ffb0/requests_toolbelt-0.8.0-py2.py3-none-any.whl (54kB)
#     100% |████████████████████████████████| 61kB 7.3MB/s
# Collecting future>=0.16.0 (from agavepy)
#   Downloading https://files.pythonhosted.org/packages/00/2b/8d082ddfed935f3608cc61140df6dcbf0edea1bc3ab52fb6c29ae3e81e85/future-0.16.0.tar.gz (824kB)
#     100% |████████████████████████████████| 829kB 1.7MB/s
# Requirement already satisfied: markupsafe in /Users/scleveland/anaconda/envs/py36/lib/python3.6/site-packages (from Jinja2==2.7.3->agavepy)
# Requirement already satisfied: setuptools in /Users/scleveland/anaconda/envs/py36/lib/python3.6/site-packages (from pytest>=2.7.0->agavepy)
# Requirement already satisfied: attrs>=17.2.0 in /Users/scleveland/anaconda/envs/py36/lib/python3.6/site-packages (from pytest>=2.7.0->agavepy)
# Requirement already satisfied: pluggy<0.7,>=0.5 in /Users/scleveland/anaconda/envs/py36/lib/python3.6/site-packages (from pytest>=2.7.0->agavepy)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/scleveland/anaconda/envs/py36/lib/python3.6/site-packages (from requests>=2.6.0->agavepy)
# Requirement already satisfied: idna<2.7,>=2.5 in /Users/scleveland/anaconda/envs/py36/lib/python3.6/site-packages (from requests>=2.6.0->agavepy)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /Users/scleveland/anaconda/envs/py36/lib/python3.6/site-packages (from requests>=2.6.0->agavepy)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/scleveland/anaconda/envs/py36/lib/python3.6/site-packages (from requests>=2.6.0->agavepy)
# Building wheels for collected packages: agavepy, Jinja2, backports.ssl-match-hostname, future
#   Running setup.py bdist_wheel for agavepy ... done
#   Stored in directory: /Users/scleveland/Library/Caches/pip/wheels/84/7a/f6/84d22b0c479e47b7236dcff3d752f4fef3bc188c33a5fc3eb8
#   Running setup.py bdist_wheel for Jinja2 ... done
#   Stored in directory: /Users/scleveland/Library/Caches/pip/wheels/01/a3/34/1e8ce0a7bfc263c9cc7c87db665fd431105d7be00e289cd69f
#   Running setup.py bdist_wheel for backports.ssl-match-hostname ... done
#   Stored in directory: /Users/scleveland/Library/Caches/pip/wheels/99/7e/f7/a88a9bcf7a3bd6b12cf6a74eee8c89746aaa02f71ab7b33939
#   Running setup.py bdist_wheel for future ... done
#   Stored in directory: /Users/scleveland/Library/Caches/pip/wheels/bf/c9/a3/c538d90ef17cf7823fa51fc701a7a7a910a80f6a405bf15b1a
# Successfully built agavepy Jinja2 backports.ssl-match-hostname future
# Installing collected packages: Jinja2, backports.ssl-match-hostname, websocket-client, requests-toolbelt, future, agavepy
#   Found existing installation: Jinja2 2.10
#     Uninstalling Jinja2-2.10:
#       Successfully uninstalled Jinja2-2.10
# Successfully installed Jinja2-2.7.3 agavepy-0.7.0 backports.ssl-match-hostname-3.5.0.1 future-0.16.0 requests-toolbelt-0.8.0 websocket-client-0.47.0
# You are using pip version 9.0.1, however version 10.0.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# The agavepy library provides a high-level Python binding to the Agave API. The first step is to import the Agave class:

# %%
from agavepy.agave import Agave
import re
import os
import sys
from time import sleep

# This cell enables inline plotting in the notebook
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import json

# %% [markdown]
# The first thing we need to do to work with the Agave APIs is to define what Agave instance "tenant" we are going to connect to and what credentials to use to do so.  We will assign 'ag' our Agave OAuth connection object for connecting to the UH HPC Tenant using your UH login credentials.

# %%
ag = Agave(api_server='https://uhhpctenant.its.hawaii.edu',
username=os.environ['AGAVE_USERNAME'],
password=os.environ['AGAVE_PASSWORD'])

# %% [markdown]
# Before we can interact with UH Agave Tenant, we need to instantiate a client session.

# %%
ag.clients.list()
# Out:
# [{'description': '',
#   'name': 'agave-togo',
#   'consumerKey': 'kYBOf_tsDEk_12y5WBiwteHuXxUa',
#   '_links': {'subscriber': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#    'self': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/agave-togo'},
#    'subscriptions': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/agave-togo/subscriptions/'}},
#   'tier': 'Unlimited',
#   'callbackUrl': 'https://uphpctenant.its.hawaii.edu/'},
#  {'description': '',
#   'name': 'anewtestrer',
#   'consumerKey': 'FVW5LRld7W2bUZz645UaUgdqn40a',
#   '_links': {'subscriber': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#    'self': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/anewtestrer'},
#    'subscriptions': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/anewtestrer/subscriptions/'}},
#   'tier': 'Unlimited',
#   'callbackUrl': ''},
#  {'description': None,
#   'name': 'DefaultApplication',
#   'consumerKey': 'AtfPPXtOGv0fO8r8JMh5xF7SrpAa',
#   '_links': {'subscriber': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#    'self': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/DefaultApplication'},
#    'subscriptions': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/DefaultApplication/subscriptions/'}},
#   'tier': 'Unlimited',
#   'callbackUrl': None},
#  {'description': 'Autogenerated cli client application generated by seanbc on Thu Apr 19 01:25:43 UTC 2018',
#   'name': 'funwave-tvd--seanbc',
#   'consumerKey': '3Dk_yS4ANVf7wAR5HBBdFQ0OfwAa',
#   '_links': {'subscriber': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#    'self': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/funwave-tvd--seanbc'},
#    'subscriptions': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/funwave-tvd--seanbc/subscriptions/'}},
#   'tier': 'Unlimited',
#   'callbackUrl': ''},
#  {'description': 'Autogenerated cli client application generated by seanbc on Thu Apr 19 06:30:13 UTC 2018',
#   'name': 'funwave-tvd-hawaii-seanbc',
#   'consumerKey': 'qT0LyKSLnH8ZB5lde0LYBC_91kga',
#   '_links': {'subscriber': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#    'self': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/funwave-tvd-hawaii-seanbc'},
#    'subscriptions': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/funwave-tvd-hawaii-seanbc/subscriptions/'}},
#   'tier': 'Unlimited',
#   'callbackUrl': ''},
#  {'description': 'Autogenerated cli client application generated by seanbc on Wed Apr 18 18:14:26 UTC 2018',
#   'name': 'funwave-tvd-sc17-seanbc',
#   'consumerKey': 'yfSPrjOf5YAkrN4ZM4vEHd_L3D0a',
#   '_links': {'subscriber': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#    'self': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/funwave-tvd-sc17-seanbc'},
#    'subscriptions': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/funwave-tvd-sc17-seanbc/subscriptions/'}},
#   'tier': 'Unlimited',
#   'callbackUrl': ''},
#  {'description': '',
#   'name': 'hpcgw',
#   'consumerKey': 'hkXI4GfDHyL8roP2NG30UTWmUUUa',
#   '_links': {'subscriber': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#    'self': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/hpcgw'},
#    'subscriptions': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/hpcgw/subscriptions/'}},
#   'tier': 'Unlimited',
#   'callbackUrl': 'http://uhhpcgw.its.hawaii.edu/auth/'},
#  {'description': '',
#   'name': 'hpcgw-togo',
#   'consumerKey': 'kUf8KsAxnk5HBDFE2vmAhMGfTiIa',
#   '_links': {'subscriber': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#    'self': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/hpcgw-togo'},
#    'subscriptions': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/hpcgw-togo/subscriptions/'}},
#   'tier': 'Unlimited',
#   'callbackUrl': 'https://uhhpcgw.its.hawaii.edu/auth/'},
#  {'description': '',
#   'name': 'my_client',
#   'consumerKey': '7qgz6sCbDiCfh5fQ60JdcDzujpwa',
#   '_links': {'subscriber': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#    'self': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/my_client'},
#    'subscriptions': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/my_client/subscriptions/'}},
#   'tier': 'Unlimited',
#   'callbackUrl': ''},
#  {'description': '',
#   'name': 'my_client2',
#   'consumerKey': 'HXu0ukajqDmhkWNv3sQ4QA0RpGca',
#   '_links': {'subscriber': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#    'self': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/my_client2'},
#    'subscriptions': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/my_client2/subscriptions/'}},
#   'tier': 'Unlimited',
#   'callbackUrl': ''},
#  {'description': '',
#   'name': 'my_client3',
#   'consumerKey': 'iSlCH_BQ5OhfHz1mhy4NSpXyYEEa',
#   '_links': {'subscriber': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#    'self': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/my_client3'},
#    'subscriptions': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/my_client3/subscriptions/'}},
#   'tier': 'Unlimited',
#   'callbackUrl': ''},
#  {'description': '',
#   'name': 'my_client4',
#   'consumerKey': 'hxXc5CL4sxz7YNUkDTebkWCzDHEa',
#   '_links': {'subscriber': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#    'self': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/my_client4'},
#    'subscriptions': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/my_client4/subscriptions/'}},
#   'tier': 'Unlimited',
#   'callbackUrl': ''},
#  {'description': '',
#   'name': 'my_client5',
#   'consumerKey': 'wpLRw5kf_S1L0SvqWOuW2yE4D0Qa',
#   '_links': {'subscriber': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#    'self': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/my_client5'},
#    'subscriptions': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/my_client5/subscriptions/'}},
#   'tier': 'Unlimited',
#   'callbackUrl': ''},
#  {'description': '',
#   'name': 'my_client6',
#   'consumerKey': 'jYys5kyTUkSlPXCgofm8mr9ZMfoa',
#   '_links': {'subscriber': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#    'self': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/my_client6'},
#    'subscriptions': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/my_client6/subscriptions/'}},
#   'tier': 'Unlimited',
#   'callbackUrl': ''},
#  {'description': '',
#   'name': 'my_client7',
#   'consumerKey': '8lPjnUD49Ltb1PKwFDVXhW0XbJAa',
#   '_links': {'subscriber': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#    'self': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/my_client7'},
#    'subscriptions': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/my_client7/subscriptions/'}},
#   'tier': 'Unlimited',
#   'callbackUrl': ''},
#  {'description': '',
#   'name': 'my_client8',
#   'consumerKey': 'Q41t7p23bhHy1jOhtRsjQaBLk6wa',
#   '_links': {'subscriber': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#    'self': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/my_client8'},
#    'subscriptions': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/my_client8/subscriptions/'}},
#   'tier': 'Unlimited',
#   'callbackUrl': ''},
#  {'description': '',
#   'name': 'my_client9',
#   'consumerKey': 'cdBMLnaOQHMy51_LjHd4H7XP63Ua',
#   '_links': {'subscriber': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#    'self': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/my_client9'},
#    'subscriptions': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/my_client9/subscriptions/'}},
#   'tier': 'Unlimited',
#   'callbackUrl': ''},
#  {'description': 'Jenkins training host for seanbc',
#   'name': 'seanbc-jenkins-training',
#   'consumerKey': 'VvuslOgykoKOhO3fjV_AmUQH0_4a',
#   '_links': {'subscriber': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#    'self': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/seanbc-jenkins-training'},
#    'subscriptions': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/seanbc-jenkins-training/subscriptions/'}},
#   'tier': 'Unlimited',
#   'callbackUrl': '8a89b59a64f5/jenkins'},
#  {'description': '',
#   'name': 'testapp',
#   'consumerKey': 'JsgcT5QU_9MRgeGnkkuGDQWqLWEa',
#   '_links': {'subscriber': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#    'self': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/testapp'},
#    'subscriptions': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/testapp/subscriptions/'}},
#   'tier': 'Unlimited',
#   'callbackUrl': ''},
#  {'description': '',
#   'name': 'testapp2',
#   'consumerKey': 'mFNc9EWTpNTKasy3Up9YXo8XFFoa',
#   '_links': {'subscriber': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#    'self': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/testapp2'},
#    'subscriptions': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/testapp2/subscriptions/'}},
#   'tier': 'Unlimited',
#   'callbackUrl': ''},
#  {'description': '',
#   'name': 'testingclient',
#   'consumerKey': 'SOufucltwPUuwi6IXYoxhbzgOM4a',
#   '_links': {'subscriber': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#    'self': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/testingclient'},
#    'subscriptions': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/testingclient/subscriptions/'}},
#   'tier': 'Unlimited',
#   'callbackUrl': ''}]

# %% [markdown]
# You will observe that you should have no clients currently.
# Will use the client constructor by adding the name of the client we want to define. Our login/auth credentials have already been stored in the 'ag' Agave OAuth object instance so we do not need to put them in again. Upon client creation we will have generated an Oauth session for working with the Agave APIs hosted by UH.
#
# We will first delete the client in case we are running this more than once.

# %%
ag.clients.delete(clientName='my_client')
# Out:
# {}

# %%
ag.clients.create(body={'clientName': 'my_client'})
# Out:
# {'description': '',
#  'name': 'my_client',
#  'consumerKey': 'helL97SXqhSvJI7sYR3ujMib6oga',
#  '_links': {'subscriber': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#   'self': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/my_client'},
#   'subscriptions': {'href': 'https://uhhpctenant.its.hawaii.edu/clients/v2/my_client/subscriptions/'}},
#  'tier': 'Unlimited',
#  'consumerSecret': 'JmggDSe5mNoTUSMqBNe5E3atI9sa',
#  'callbackUrl': ''}

# %% [markdown]
# <div style="background:#eee;border:1px solid #ccc;padding:5px 10px;"><em>The agavepy library&#39;s Agave class also provides a restore() method for reconstituting previous OAuth sessions. Previous sessions are read from and written to a cache file, /etc/.agpy, so that OAuth sessions persist across iPython sessions. When you authenticated to JupyterHub, the OAuth login was written to the .agpy file. We can therefore use the restore method to create an OAuth client without needing to pass any credentials:</em></div>
#
# <div style="background:#eee;border:1px solid #ccc;padding:5px 10px;"><em>Note that the restore method can take arguments (such as client_name) so that you can restore/manage multiple OAuth sessions. When first getting started on the hub, there is only one session in the cache file, so no arguments are required.</em></div>

# %% [markdown]
# If we ever want to inspect the OAuth session being used by our client, we have a few methods available to us. First, we can print the token_info dictionary on the token object:

# %%
ag.token.token_info
# Out:
# {u'access_token': u'e4fd3e3bdc761f17efe97d296be43396',
#  'created_at': 1523851691,
#  'expiration': 1523866091,
#  'expires_at': 'Sun Apr 15 22:08:11 2018',
#  u'expires_in': 14400,
#  u'refresh_token': u'f19b4ef976cc369b625aa84726a534',
#  u'scope': u'default',
#  u'token_type': u'bearer'}

# %%
ag.token.refresh()
# Out:
# u'51a44c8ecf6f702388a7d8252dad42a2'

# %%
ag.token.token_info
# Out:
# {u'access_token': u'51a44c8ecf6f702388a7d8252dad42a2',
#  'created_at': 1523851698,
#  'expiration': 1523866098,
#  'expires_at': 'Sun Apr 15 22:08:18 2018',
#  u'expires_in': 14400,
#  u'refresh_token': u'63c44c32b5fcb4c6bd19f6e17ee833',
#  u'scope': u'default',
#  u'token_type': u'bearer'}

# %% [markdown]
# This shows us both the access and refresh tokens being used. We can also see the end user profile associated with these tokens:

# %%
ag.profiles.get()
# Out:
# {u'create_time': u'',
#  u'email': u'seanbc@hawaii.edu',
#  u'first_name': u'Sean',
#  u'full_name': u'Sean B Cleveland',
#  u'last_name': u'Cleveland',
#  u'mobile_phone': u'',
#  u'phone': u'(808) 956-8982',
#  u'status': u'',
#  u'username': u'seanbc'}

# %% [markdown]
# Finally, we can inspect the ag object directly for attributes like api_key, api_secret, api_server, etc.

# %%
print ag.api_key, ag.api_secret, ag.api_server
# Out:
# 7qgz6sCbDiCfh5fQ60JdcDzujpwa RM021_WqJln0ckgA7MOcNmI8Q_4a https://uhhpctenant.its.hawaii.edu

# %% [markdown]
# We are now ready to interact with Agave services using our agavepy client. We can take a quick look at the available top-level methods of our client:

# %%
dir(ag)
# Out:
# [u'actors',
#  u'admin',
#  u'apps',
#  u'clients',
#  u'files',
#  u'jobs',
#  u'meta',
#  u'monitors',
#  u'notifications',
#  u'postits',
#  u'profiles',
#  u'systems',
#  u'transforms']

# %% [markdown]
# We see there is a top-level method for each of the core science APIs in agave. We will focus on the apps service since it is of broad interest, but much of what we illustrate is generally applicable to all Agave core science APIs.
#
# We can browse a specific collection using the list() method. For example, let's see what apps are available to us:

# %%
ag.apps.list()
# Out:
# [{'id': 'seanbc-sandbox-funwave-1.0',
#   'name': 'seanbc-sandbox-funwave',
#   'version': '1.0',
#   'revision': 1,
#   'executionSystem': 'hawaii-exec-seanbc',
#   'shortDescription': 'Runs a command',
#   'isPublic': False,
#   'label': 'Runs a command',
#   'lastModified': datetime.datetime(2018, 4, 19, 3, 57, 56, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/seanbc-sandbox-funwave-1.0'}}},
#  {'id': 'deardooley-sandbox-fork-1.0',
#   'name': 'deardooley-sandbox-fork',
#   'version': '1.0',
#   'revision': 1,
#   'executionSystem': 'hawaii-exec-deardooley',
#   'shortDescription': 'Runs a command',
#   'isPublic': False,
#   'label': 'Runs a command',
#   'lastModified': datetime.datetime(2018, 4, 19, 2, 51, 46, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/deardooley-sandbox-fork-1.0'}}},
#  {'id': 'seanbc-sandbox-fork-1.0',
#   'name': 'seanbc-sandbox-fork',
#   'version': '1.0',
#   'revision': 2,
#   'executionSystem': 'hawaii-exec-seanbc',
#   'shortDescription': 'Runs a command',
#   'isPublic': False,
#   'label': 'Runs a command',
#   'lastModified': datetime.datetime(2018, 4, 19, 1, 32, 10, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/seanbc-sandbox-fork-1.0'}}},
#  {'id': 'uh-hpc-singularity-runner-0.1.0',
#   'name': 'uh-hpc-singularity-runner',
#   'version': '0.1.0',
#   'revision': 2,
#   'executionSystem': 'execute.uhhpc1.its.hawaii.edu',
#   'shortDescription': 'This will execute whatever command you give in the command parameter',
#   'isPublic': False,
#   'label': 'Execute a command in a singularity hub container',
#   'lastModified': datetime.datetime(2018, 4, 16, 20, 45, 45, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/uh-hpc-singularity-runner-0.1.0'}}},
#  {'id': 'uh-hpc-docker-runner-0.1.0',
#   'name': 'uh-hpc-docker-runner',
#   'version': '0.1.0',
#   'revision': 5,
#   'executionSystem': 'execute.uhhpc1.its.hawaii.edu',
#   'shortDescription': 'This will execute whatever command you give in the command parameter',
#   'isPublic': False,
#   'label': 'Execute a command in a docker container via singularity',
#   'lastModified': datetime.datetime(2018, 4, 16, 19, 47, 41, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/uh-hpc-docker-runner-0.1.0'}}},
#  {'id': 'cdudoit-ggplot-uhhpc-1.0',
#   'name': 'cdudoit-ggplot-uhhpc',
#   'version': '1.0',
#   'revision': 1,
#   'executionSystem': 'cdudoit-uhhpc-execution',
#   'shortDescription': 'Plot a genome using ggplot',
#   'isPublic': False,
#   'label': 'Genome Plot',
#   'lastModified': datetime.datetime(2017, 4, 12, 21, 18, 49, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/cdudoit-ggplot-uhhpc-1.0'}}},
#  {'id': 'hurleyk-uhhpc-ggplot-1.0',
#   'name': 'hurleyk-uhhpc-ggplot',
#   'version': '1.0',
#   'revision': 2,
#   'executionSystem': 'hurleyk-uhhpc-exec',
#   'shortDescription': 'Plot a genome using ggplot',
#   'isPublic': False,
#   'label': 'Genome Plot',
#   'lastModified': datetime.datetime(2017, 4, 12, 21, 14, 19, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/hurleyk-uhhpc-ggplot-1.0'}}},
#  {'id': 'jgeis-ggplot2-uhhpc-1.0',
#   'name': 'jgeis-ggplot2-uhhpc',
#   'version': '1.0',
#   'revision': 1,
#   'executionSystem': 'jgeis-hpc-execution',
#   'shortDescription': 'Plot a genome using ggplot',
#   'isPublic': False,
#   'label': 'Genome Plot',
#   'lastModified': datetime.datetime(2017, 4, 12, 21, 8, 55, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/jgeis-ggplot2-uhhpc-1.0'}}},
#  {'id': 'maortega-ggplot-uhhpc-1.0',
#   'name': 'maortega-ggplot-uhhpc',
#   'version': '1.0',
#   'revision': 1,
#   'executionSystem': 'maortega-uhhpc-exec',
#   'shortDescription': 'Plot a genome using ggplot',
#   'isPublic': False,
#   'label': 'Genome Plot',
#   'lastModified': datetime.datetime(2017, 4, 12, 21, 6, 31, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/maortega-ggplot-uhhpc-1.0'}}},
#  {'id': 'iknapp-ggplot-uhhpc-1.0',
#   'name': 'iknapp-ggplot-uhhpc',
#   'version': '1.0',
#   'revision': 1,
#   'executionSystem': 'iknapp-uhhpc-exe',
#   'shortDescription': 'Plot a genome using ggplot',
#   'isPublic': False,
#   'label': 'Genome Plot',
#   'lastModified': datetime.datetime(2017, 4, 12, 21, 4, 43, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/iknapp-ggplot-uhhpc-1.0'}}},
#  {'id': 'shayle-ggplot-uhhpc-1.0',
#   'name': 'shayle-ggplot-uhhpc',
#   'version': '1.0',
#   'revision': 2,
#   'executionSystem': 'shayle-uhhpc-exec',
#   'shortDescription': 'Plot a genome using ggplot',
#   'isPublic': False,
#   'label': 'Genome Plot',
#   'lastModified': datetime.datetime(2017, 4, 12, 21, 4, 16, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/shayle-ggplot-uhhpc-1.0'}}},
#  {'id': 'akijl-ggplot-uhhpc-1.0',
#   'name': 'akijl-ggplot-uhhpc',
#   'version': '1.0',
#   'revision': 1,
#   'executionSystem': 'akijl-uhhpc-execute',
#   'shortDescription': 'Plot a genome using ggplot',
#   'isPublic': False,
#   'label': 'Genome Plot',
#   'lastModified': datetime.datetime(2017, 4, 12, 21, 3, 14, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/akijl-ggplot-uhhpc-1.0'}}},
#  {'id': 'canfield-ggplot-uhhpc-1.0',
#   'name': 'canfield-ggplot-uhhpc',
#   'version': '1.0',
#   'revision': 1,
#   'executionSystem': 'canfield-uhhpc-exe',
#   'shortDescription': 'Plot a genome using ggplot',
#   'isPublic': False,
#   'label': 'Genome Plot',
#   'lastModified': datetime.datetime(2017, 4, 12, 21, 2, 23, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/canfield-ggplot-uhhpc-1.0'}}},
#  {'id': 'jgeis-ggplot-uhhpc-1.0',
#   'name': 'jgeis-ggplot-uhhpc',
#   'version': '1.0',
#   'revision': 1,
#   'executionSystem': 'jgeis-hpc-execution',
#   'shortDescription': 'Plot a genome using ggplot',
#   'isPublic': False,
#   'label': 'Genome Plot',
#   'lastModified': datetime.datetime(2017, 4, 12, 21, 1, 47, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/jgeis-ggplot-uhhpc-1.0'}}},
#  {'id': 'angeldve-ggplot-uhhpc-1.0',
#   'name': 'angeldve-ggplot-uhhpc',
#   'version': '1.0',
#   'revision': 1,
#   'executionSystem': 'angeldve-uhhpc-exec',
#   'shortDescription': 'Plot a genome using ggplot',
#   'isPublic': False,
#   'label': 'Genome Plot',
#   'lastModified': datetime.datetime(2017, 4, 12, 21, 0, 51, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/angeldve-ggplot-uhhpc-1.0'}}},
#  {'id': 'enalley-ggplot-uhhpc-1.0',
#   'name': 'enalley-ggplot-uhhpc',
#   'version': '1.0',
#   'revision': 1,
#   'executionSystem': 'enalley-uhhpc-exec',
#   'shortDescription': 'Plot a genome using ggplot',
#   'isPublic': False,
#   'label': 'Genome Plot',
#   'lastModified': datetime.datetime(2017, 4, 12, 21, 0, 49, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/enalley-ggplot-uhhpc-1.0'}}},
#  {'id': 'rcolema-ggplot-uhhpc-1.0',
#   'name': 'rcolema-ggplot-uhhpc',
#   'version': '1.0',
#   'revision': 1,
#   'executionSystem': 'rcolema-uhhpc-exec',
#   'shortDescription': 'Plot a genome using ggplot',
#   'isPublic': False,
#   'label': 'Genome Plot',
#   'lastModified': datetime.datetime(2017, 4, 12, 21, 0, 31, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/rcolema-ggplot-uhhpc-1.0'}}},
#  {'id': 'mmenor-ggplot-uhhpc-1.0',
#   'name': 'mmenor-ggplot-uhhpc',
#   'version': '1.0',
#   'revision': 1,
#   'executionSystem': 'mmenor-uhhpc-exec',
#   'shortDescription': 'Plot a genome using ggplot',
#   'isPublic': False,
#   'label': 'Genome Plot',
#   'lastModified': datetime.datetime(2017, 4, 12, 21, 0, 29, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/mmenor-ggplot-uhhpc-1.0'}}},
#  {'id': 'onigro-ggplot-uhhpc-1.0',
#   'name': 'onigro-ggplot-uhhpc',
#   'version': '1.0',
#   'revision': 1,
#   'executionSystem': 'onigro-uhhpc-execution',
#   'shortDescription': 'Plot a genome using ggplot',
#   'isPublic': False,
#   'label': 'Genome Plot',
#   'lastModified': datetime.datetime(2017, 4, 12, 21, 0, 21, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/onigro-ggplot-uhhpc-1.0'}}},
#  {'id': 'eee-ggplot-uhhpc-1.0',
#   'name': 'eee-ggplot-uhhpc',
#   'version': '1.0',
#   'revision': 1,
#   'executionSystem': 'eee-uuhpc-execution',
#   'shortDescription': 'Plot a genome using ggplot',
#   'isPublic': False,
#   'label': 'Genome Plot',
#   'lastModified': datetime.datetime(2017, 4, 12, 21, 0, 21, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/eee-ggplot-uhhpc-1.0'}}},
#  {'id': 'aludert-ggplot-uhhpc-1.0',
#   'name': 'aludert-ggplot-uhhpc',
#   'version': '1.0',
#   'revision': 1,
#   'executionSystem': 'aludert-uhhpc-exec',
#   'shortDescription': 'Plot a genome using ggplot',
#   'isPublic': False,
#   'label': 'Genome Plot',
#   'lastModified': datetime.datetime(2017, 4, 12, 21, 0, 19, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/aludert-ggplot-uhhpc-1.0'}}},
#  {'id': 'blensing-ggplot-uhhpc-1.0',
#   'name': 'blensing-ggplot-uhhpc',
#   'version': '1.0',
#   'revision': 1,
#   'executionSystem': 'blensing-uhhpc-exec',
#   'shortDescription': 'Plot a genome using ggplot',
#   'isPublic': False,
#   'label': 'Genome Plot',
#   'lastModified': datetime.datetime(2017, 4, 12, 21, 0, 15, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/blensing-ggplot-uhhpc-1.0'}}},
#  {'id': 'schvarcz-ggplot-uhhpc-1.0',
#   'name': 'schvarcz-ggplot-uhhpc',
#   'version': '1.0',
#   'revision': 1,
#   'executionSystem': 'schvarcz-uhhpc-exec',
#   'shortDescription': 'Plot a genome using ggplot',
#   'isPublic': False,
#   'label': 'Genome Plot',
#   'lastModified': datetime.datetime(2017, 4, 12, 21, 0, 15, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/schvarcz-ggplot-uhhpc-1.0'}}},
#  {'id': 'jfonner-ggplot-uhhpc-041217-1.0',
#   'name': 'jfonner-ggplot-uhhpc-041217',
#   'version': '1.0',
#   'revision': 1,
#   'executionSystem': 'jfonner-uhhpc-exec',
#   'shortDescription': 'Plot a genome using ggplot',
#   'isPublic': False,
#   'label': 'Genome Plot',
#   'lastModified': datetime.datetime(2017, 4, 12, 18, 36, 39, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/jfonner-ggplot-uhhpc-041217-1.0'}}}]

# %% [markdown]
# What we see in the output above is a python list representing the JSON object returned from Agave's apps service. It is a list of objects, each of which representing a single app. Let's capture the first app object and inspect it. To do that we can use normal Python list notation:

# %%
app = ag.apps.list()[0]

# %%
app.__class__
# Out:
# agavepy.agave.AttrDict

# %% [markdown]
# We see that the app object is of type agavepy.agave.AttrDict. That's a Python dictionary with some customizations to provide convenience features such as using dot notation for keys/attributes. For example, we see that the app object has an 'id' key. We can access it directly using dot notation:

# %%
app.id
# Out:
# 'seanbc-sandbox-funwave-1.0'

# %% [markdown]
# Equivalently, we can use normal Python dictionary syntax:

# %% [markdown]
# app['id']In Agave, the app id is the unique identifier for the application. We'll come back to that in a minute. For now, just know that this example is very typical of responses from agavepy: in general the JSON response object is represented by lists of AttrDicts.
#
# Stepping back for a second, let's explore the apps collection a bit. We can always get a list of operations available for a collection by using the dir(-) method:

# %%
dir(ag.apps)
# Out:
# ['add',
#  'delete',
#  'deletePermissions',
#  'deletePermissionsForUser',
#  'get',
#  'getJobSubmissionForm',
#  'list',
#  'listByName',
#  'listByOntologyTerm',
#  'listBySystemId',
#  'listByTag',
#  'listPermissions',
#  'listPermissionsForUser',
#  'manage',
#  'update',
#  'updateApplicationPermissions',
#  'updatePermissionsForUser']

# %% [markdown]
# Also notice that we have tab-completion on these operations. So, if we start typing "ag.apps.l" and then hit tab, Jupyter provides a select box of operations beginning with "l". Try putting the following cell in focus and then hitting the tab key (but don't actually hit enter or try to execute the cell; otherwise you'll get an exception because there's no method called "l"):

# %%
ag.apps.l
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-27cccf508dc3> in <module>()
# ----> 1 ag.apps.l
#
# ~/src/agavepy/agavepy/agave.py in __getattr__(self, attr)
#     495
#     496     def __getattr__(self, attr):
# --> 497         return Operation(self.resource, attr, client=self.client)
#     498
#     499     def __dir__(self):
#
# ~/src/agavepy/agavepy/agave.py in __init__(self, resource, operation, client)
#     523
#     524         self.models = self.get_models()
# --> 525         self.return_type = self.get_return_type()
#     526
#     527     def get_base(self):
#
# ~/src/agavepy/agavepy/agave.py in get_return_type(self)
#     544         """Get JSON with the return type for this operation."""
#     545
# --> 546         return self.get_operation().json
#     547
#     548     def __call__(self, *args, **kwargs):
#
# ~/src/agavepy/agavepy/agave.py in get_operation(self)
#     533     def get_operation(self):
#     534         base = self.get_base()
# --> 535         return getattr(getattr(base, self.resource), self.operation)
#     536
#     537     def get_models(self):
#
# ~/src/agavepy/agavepy/swaggerpy/client.py in __getattr__(self, item)
#     211         if not op:
#     212             raise AttributeError("Resource '%s' has no operation '%s'" %
# --> 213                                  (self.get_name(), item))
#     214         return op
#     215
#
# AttributeError: Resource 'apps' has no operation 'l'

# %% [markdown]
# If we would like to get details about a specific object for which we know the unique id, in general we use the get method, passing in the id for the object. Here, we will use an app id we found from the ag.apps.list command.

# %%
ag.apps.get(appId=app.id)
# Out:
# {'id': 'seanbc-sandbox-funwave-1.0',
#  'name': 'seanbc-sandbox-funwave',
#  'icon': None,
#  'uuid': '4624972034765549080-242ac118-0001-005',
#  'parallelism': 'SERIAL',
#  'defaultProcessorsPerNode': 1,
#  'defaultMemoryPerNode': 1,
#  'defaultNodeCount': 1,
#  'defaultMaxRunTime': None,
#  'defaultQueue': None,
#  'version': '1.0',
#  'revision': 1,
#  'isPublic': False,
#  'helpURI': None,
#  'label': 'Runs a command',
#  'owner': 'seanbc',
#  'shortDescription': 'Runs a command',
#  'longDescription': '',
#  'tags': [],
#  'ontology': [],
#  'executionType': 'CLI',
#  'executionSystem': 'hawaii-exec-seanbc',
#  'deploymentPath': 'funwave-agave-deployment',
#  'deploymentSystem': 'hawaii-storage-seanbc',
#  'templatePath': 'funwave-wrapper.txt',
#  'testPath': 'funwave-test.txt',
#  'checkpointable': False,
#  'lastModified': datetime.datetime(2018, 4, 19, 3, 57, 56, tzinfo=tzoffset(None, -18000)),
#  'modules': [],
#  'available': True,
#  'inputs': [],
#  'parameters': [{'id': 'compress_output',
#    'value': {'visible': True,
#     'required': True,
#     'type': 'bool',
#     'order': 0,
#     'enquote': False,
#     'default': True,
#     'validator': None},
#    'details': {'label': 'Compress output folder',
#     'description': 'If true, output will be packed and compressed',
#     'argument': None,
#     'showArgument': False,
#     'repeatArgument': False},
#    'semantics': {'minCardinality': 1, 'maxCardinality': 1, 'ontology': []}},
#   {'id': 'AMP',
#    'value': {'visible': True,
#     'required': True,
#     'type': 'string',
#     'order': 0,
#     'enquote': False,
#     'default': '3.0',
#     'validator': '\\d+\\.\\d+'},
#    'details': {'label': 'Wave amplitude',
#     'description': 'Wave amplitude expressed as a decimal value',
#     'argument': None,
#     'showArgument': False,
#     'repeatArgument': False},
#    'semantics': {'minCardinality': 1, 'maxCardinality': 1, 'ontology': []}},
#   {'id': 'WID',
#    'value': {'visible': True,
#     'required': True,
#     'type': 'string',
#     'order': 0,
#     'enquote': False,
#     'default': '25.0',
#     'validator': '\\d+\\.\\d+'},
#    'details': {'label': 'Width',
#     'description': 'Width expressed as a decimal value',
#     'argument': None,
#     'showArgument': False,
#     'repeatArgument': False},
#    'semantics': {'minCardinality': 1, 'maxCardinality': 1, 'ontology': []}}],
#  'outputs': [],
#  '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/seanbc-sandbox-funwave-1.0'},
#   'executionSystem': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/hawaii-exec-seanbc'},
#   'storageSystem': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/hawaii-storage-seanbc'},
#   'history': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/seanbc-sandbox-funwave-1.0/history'},
#   'metadata': {'href': 'https://uhhpctenant.its.hawaii.edu/meta/v2/data/?q=%7B%22associationIds%22%3A%224624972034765549080-242ac118-0001-005%22%7D'},
#   'owner': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#   'permissions': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/seanbc-sandbox-funwave-1.0/pems'}}}

# %% [markdown]
# Whoa, that's a lot of information. We aren't going to give a comprehensive introduction to Agave applications in this notebook. Instead we refer you to the official Agave app tutorial on the website: http://agaveapi.co/documentation/tutorials/app-management-tutorial/
#
# However, we will point out a couple of important points. Let's capture that response in an object called full_app:

# %%
full_app = ag.apps.get(appId=app.id)

# %% [markdown]
# Complex sub-objects of the application such as application inputs and parameters come back as top level attributes. and are represented as lists. The individual elements of the list are represented as AttrDicts. We can see this by exploring our full_app's inputs:

# %%
print(full_app.inputs.__class__); print(full_app.inputs[0].__class__); full_app.inputs
# Out:
# <class 'list'>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-49fe2dce7f50> in <module>()
# ----> 1 print(full_app.inputs.__class__); print(full_app.inputs[0].__class__); full_app.inputs
#
# IndexError: list index out of range

# %%
full_app.inputs
# Out:
# []

# %% [markdown]
# Then, if we want the input id, we can use dot notation or dictionary notation just as before:

# %%
full_app.inputs[0].id

# %% [markdown]
# You now have the ability to fully explore individual Agave objects returned from agavepy, but what about searching for objects? The Agave platform provides a powerful search feature across most services, and agavepy supports that as well.
#
# Every retrieval operation in agavepy (for example, apps.list) supports a "search" argument. The syntax for the search argument is identical to that described in the Agave documentation: it uses a dot notation combining search terms, values and (optional) operators. The search object itself should be a python dictionary with strings for the keys and values. Formally, each key:value pair in the dictionary adheres to the following form:
# term.operator:value
# term.operator:value
#
# The operator is optional and defaults to equality ('eq'). For example, the following search filters the list of all apps down to just those with the id attribute equal to our app.id:

# %%
ag.apps.list(search={'id': app.id})
# Out:
# [{'id': 'seanbc-sandbox-funwave-1.0',
#   'name': 'seanbc-sandbox-funwave',
#   'version': '1.0',
#   'revision': 1,
#   'executionSystem': 'hawaii-exec-seanbc',
#   'shortDescription': 'Runs a command',
#   'isPublic': False,
#   'label': 'Runs a command',
#   'lastModified': datetime.datetime(2018, 4, 19, 3, 57, 56, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/seanbc-sandbox-funwave-1.0'}}}]

# %% [markdown]
# Equivalently, we could explicitly set the equality operator:

# %%
ag.apps.list(search={'id.eq': app.id})
# Out:
# [{'id': 'seanbc-sandbox-funwave-1.0',
#   'name': 'seanbc-sandbox-funwave',
#   'version': '1.0',
#   'revision': 1,
#   'executionSystem': 'hawaii-exec-seanbc',
#   'shortDescription': 'Runs a command',
#   'isPublic': False,
#   'label': 'Runs a command',
#   'lastModified': datetime.datetime(2018, 4, 19, 3, 57, 56, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/seanbc-sandbox-funwave-1.0'}}}]

# %% [markdown]
# Typically, the list of available search terms is identical to the attributes included in the JSON returned when requesting the full resource description. Operators include 'like', 'lt', 'gt', 'lte', 'gte', etc. See the official Agave documentation for the complete list.
#
# Here we retrieve all apps with a name is "like" *funwave:

# %%
ag.apps.list(search={'name.like': '*funwave'})
# Out:
# [{'id': 'seanbc-sandbox-funwave-1.0',
#   'name': 'seanbc-sandbox-funwave',
#   'version': '1.0',
#   'revision': 1,
#   'executionSystem': 'hawaii-exec-seanbc',
#   'shortDescription': 'Runs a command',
#   'isPublic': False,
#   'label': 'Runs a command',
#   'lastModified': datetime.datetime(2018, 4, 19, 3, 57, 56, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/seanbc-sandbox-funwave-1.0'}}}]

# %% [markdown]
# Two results were returned, both with name "opensees".
#
# You can include multiple search expressions in the form of additional key:value pairs to build a more restrictive query. Here we restrict the result to opensees apps with revision at least 25:

# %%
ag.apps.list(search={'name.like': '*funwave', 'revision.gte': 1})
# Out:
# [{'id': 'seanbc-sandbox-funwave-1.0',
#   'name': 'seanbc-sandbox-funwave',
#   'version': '1.0',
#   'revision': 1,
#   'executionSystem': 'hawaii-exec-seanbc',
#   'shortDescription': 'Runs a command',
#   'isPublic': False,
#   'label': 'Runs a command',
#   'lastModified': datetime.datetime(2018, 4, 19, 3, 57, 56, tzinfo=tzoffset(None, -18000)),
#   '_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/apps/v2/seanbc-sandbox-funwave-1.0'}}}]

# %% [markdown]
# We hope this gives you enough general information to begin exploring the Agave services using agavepy on your own. In subsequent notebooks, we'll take deeper dives into specific topics such as using agavepy to launch and monitor an Agave job.

# %%
ag.systems.list()
# Out:
# [{'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'default': False,
#   'description': 'lustres on uh hpc',
#   'id': 'uhhpc-lustre-storage',
#   'lastUpdated': '2018-04-17T19:24:10.000-05:00',
#   'name': 'uhhpc-lustre-storage',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/execute.uhhpc1.its.hawaii.edu'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC.',
#   'id': 'execute.uhhpc1.its.hawaii.edu',
#   'lastUpdated': '2018-04-16T18:48:00.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uh-hpc-lustre'}},
#   'default': True,
#   'description': 'UH HPC Lustre Storage',
#   'id': 'uh-hpc-lustre',
#   'lastUpdated': '2018-04-16T13:03:00.000-05:00',
#   'name': 'UH HPC Lustre',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'jgeis-hpc-execution',
#   'lastUpdated': '2017-04-12T21:13:33.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/blensing-uhhpc-exec'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'blensing-uhhpc-exec',
#   'lastUpdated': '2017-04-12T21:11:05.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/akijl-uhhpc-execute'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'akijl-uhhpc-execute',
#   'lastUpdated': '2017-04-12T21:07:48.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-storage-maortega'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'uhhpc-storage-maortega',
#   'lastUpdated': '2017-04-12T21:03:49.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/bennypb-hpc-execution'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'bennypb-hpc-execution',
#   'lastUpdated': '2017-04-12T20:53:11.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/angeldve-uhhpc-exec'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'angeldve-uhhpc-exec',
#   'lastUpdated': '2017-04-12T20:51:31.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-bennypb-storage'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'uhhpc-bennypb-storage',
#   'lastUpdated': '2017-04-12T20:51:09.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/fangr-uhhpc-exec1'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'fangr-uhhpc-exec1',
#   'lastUpdated': '2017-04-12T20:49:43.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/schvarcz-uhhpc-exec'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'schvarcz-uhhpc-exec',
#   'lastUpdated': '2017-04-12T20:49:40.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/omeier-uhhpc-exec'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'omeier-uhhpc-exec',
#   'lastUpdated': '2017-04-12T20:48:13.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/falakwaa-'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'falakwaa-',
#   'lastUpdated': '2017-04-12T20:47:32.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/rosenthl-hpc-execution'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'rosenthl-hpc-execution',
#   'lastUpdated': '2017-04-12T20:47:22.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/mmenor-uhhpc-exec'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'mmenor-uhhpc-exec',
#   'lastUpdated': '2017-04-12T20:46:39.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/speck-uhhpc-exec'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'speck-uhhpc-exec',
#   'lastUpdated': '2017-04-12T20:46:27.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/aludert-uhhpc-exec'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'aludert-uhhpc-exec',
#   'lastUpdated': '2017-04-12T20:46:26.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/merrill-uhhpc-exec'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'merrill-uhhpc-exec',
#   'lastUpdated': '2017-04-12T20:46:25.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/onigro-uhhpc-execution'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'onigro-uhhpc-execution',
#   'lastUpdated': '2017-04-12T20:46:23.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/canfield-uhhpc-exe'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'canfield-uhhpc-exe',
#   'lastUpdated': '2017-04-12T20:46:22.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/enalley-uhhpc-exec'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'enalley-uhhpc-exec',
#   'lastUpdated': '2017-04-12T20:46:17.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/cdudoit-uhhpc-execution'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'cdudoit-uhhpc-execution',
#   'lastUpdated': '2017-04-12T20:46:14.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/maortega-uhhpc-exec'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'maortega-uhhpc-exec',
#   'lastUpdated': '2017-04-12T20:46:14.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/iacchei-uhhpc-exec'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'iacchei-uhhpc-exec',
#   'lastUpdated': '2017-04-12T20:46:11.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/anu42-UHHPC-exec'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'anu42-UHHPC-exec',
#   'lastUpdated': '2017-04-12T20:46:11.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/eee-uuhpc-execution'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'eee-uuhpc-execution',
#   'lastUpdated': '2017-04-12T20:46:11.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/shayle-uhhpc-exec'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'shayle-uhhpc-exec',
#   'lastUpdated': '2017-04-12T20:46:11.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/hurleyk-uhhpc-exec'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'hurleyk-uhhpc-exec',
#   'lastUpdated': '2017-04-12T20:46:11.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/iknapp-uhhpc-exe'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'iknapp-uhhpc-exe',
#   'lastUpdated': '2017-04-12T20:46:11.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/qauchida-uhhpc-exec'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'qauchida-uhhpc-exec',
#   'lastUpdated': '2017-04-12T20:46:09.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/rcolema-uhhpc-exec'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'rcolema-uhhpc-exec',
#   'lastUpdated': '2017-04-12T20:46:09.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/rosenthl-hpc-storage'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'rosenthl-hpc-storage',
#   'lastUpdated': '2017-04-12T20:43:56.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-storage'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'jgeis-hpc-storage',
#   'lastUpdated': '2017-04-12T20:39:08.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/hawaii'}},
#   'default': False,
#   'description': 'hawaii',
#   'id': 'hawaii',
#   'lastUpdated': '2017-04-12T20:36:55.000-05:00',
#   'name': 'hpc',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/enalley-uhhpc-storage1'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'enalley-uhhpc-storage1',
#   'lastUpdated': '2017-04-12T20:36:04.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/JensLustreStorage'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'JensLustreStorage',
#   'lastUpdated': '2017-04-12T20:35:52.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/akijl-uhhpc-storage'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'akijl-uhhpc-storage',
#   'lastUpdated': '2017-04-12T20:35:23.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/rcolema-uhpc-stroage2'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'rcolema-uhpc-stroage2',
#   'lastUpdated': '2017-04-12T20:34:29.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/iknapp-uhhpc-storage'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'iknapp-uhhpc-storage',
#   'lastUpdated': '2017-04-12T20:34:17.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/merrill-uhhpc-storage'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'merrill-uhhpc-storage',
#   'lastUpdated': '2017-04-12T20:32:21.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/onigro-uhhpc-storage2'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'onigro-uhhpc-storage2',
#   'lastUpdated': '2017-04-12T20:32:20.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/fangr-uhhpc1-storage1'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'fangr-uhhpc1-storage1',
#   'lastUpdated': '2017-04-12T20:32:02.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/aludert-uhhpc-storage'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'aludert-uhhpc-storage',
#   'lastUpdated': '2017-04-12T20:32:02.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/omeier-uhhpc-storage'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'omeier-uhhpc-storage',
#   'lastUpdated': '2017-04-12T20:32:01.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/speck-uhpc-lustr'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'speck-uhpc-lustr',
#   'lastUpdated': '2017-04-12T20:32:00.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/iacchei-uhhpc-storage1'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'iacchei-uhhpc-storage1',
#   'lastUpdated': '2017-04-12T20:32:00.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/qauchida-uhhpc-storage2'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'qauchida-uhhpc-storage2',
#   'lastUpdated': '2017-04-12T20:31:59.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/antaky-uhhpc-storage'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'antaky-uhhpc-storage',
#   'lastUpdated': '2017-04-12T20:31:58.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/cdudoit-uhhpc-storage'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'cdudoit-uhhpc-storage',
#   'lastUpdated': '2017-04-12T20:31:58.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/schvarcz-uhhpc-storage'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'schvarcz-uhhpc-storage',
#   'lastUpdated': '2017-04-12T20:31:55.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/eee-uhhpc-storage'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'eee-uhhpc-storage',
#   'lastUpdated': '2017-04-12T20:31:54.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/anu42-UHHPC-storage'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'anu42-UHHPC-storage',
#   'lastUpdated': '2017-04-12T20:31:54.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/mmenor-uhhpc-storage'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'mmenor-uhhpc-storage',
#   'lastUpdated': '2017-04-12T20:31:54.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/angeldve-uhhpc-storage'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'angeldve-uhhpc-storage',
#   'lastUpdated': '2017-04-12T20:31:54.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/shayle-uhhpc-storage'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'shayle-uhhpc-storage',
#   'lastUpdated': '2017-04-12T20:31:53.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/jfonner-uhhpc-storage2'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'jfonner-uhhpc-storage2',
#   'lastUpdated': '2017-04-12T20:31:53.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/canfield-uhhpc-storage'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'canfield-uhhpc-storage',
#   'lastUpdated': '2017-04-12T20:31:53.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/hurleyk-uhhpc-storage'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'hurleyk-uhhpc-storage',
#   'lastUpdated': '2017-04-12T20:31:53.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/enalley-uhhpc-storage'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'enalley-uhhpc-storage',
#   'lastUpdated': '2017-04-12T20:31:52.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/blensing-uhhpc-storage'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'blensing-uhhpc-storage',
#   'lastUpdated': '2017-04-12T20:31:50.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/jfonner-uhhpc-storage'}},
#   'default': False,
#   'description': 'UH HPC Lustre storage system using SFTP at the University of Hawaii',
#   'id': 'jfonner-uhhpc-storage',
#   'lastUpdated': '2017-04-11T20:52:51.000-05:00',
#   'name': 'UH HPC1 SFTP Lustre Storage System',
#   'public': False,
#   'status': 'UP',
#   'type': 'STORAGE'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/jfonner-uhhpc-exec'}},
#   'default': False,
#   'description': 'Execution system using ssh to submit jobs to the UH ITS HPC. By default, it uses the Sandbox queue.',
#   'id': 'jfonner-uhhpc-exec',
#   'lastUpdated': '2017-04-11T20:49:20.000-05:00',
#   'name': 'UH ITS HPC SSH Execution Host',
#   'public': False,
#   'status': 'UP',
#   'type': 'EXECUTION'}]

# %%
system_json ={
  "type": "STORAGE",
  "storage": {
    "protocol": "SFTP",
    "proxyTunnel": "NO",
    "host": "uhhpc1.its.hawaii.edu",
    "port": 22,
    "rootDir": "/lus/scratch/seanbc",
    "homeDir": "/",
    "auth": {
      "type": "SSHKEYS",
      "username": "",
      "publicKey": "",
      "privateKey": ""
    }
  },
  "id": "uhhpc-lustre-storage-seanbc",
  "name": "uhhpc-lustre-storage-seanbc",
  "status": "UP",
  "description": "lustres on uh hpc"
}

# %%
ag.systems.add(body=json_sys)
# Out:
# {'_links': {'credentials': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage/credentials'},
#   'metadata': {'href': 'https://uhhpctenant.its.hawaii.edu/meta/v2/data/?q=%7B%22associationIds%22%3A%223456389563291921944-242ac1112-0001-006%22%7D'},
#   'owner': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#   'roles': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage/roles'},
#   'self': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#  'available': True,
#  'default': False,
#  'description': 'lustres on uh hpc',
#  'globalDefault': False,
#  'id': 'uhhpc-lustre-storage',
#  'lastModified': datetime.datetime(2018, 4, 17, 19, 24, 9, 821000, tzinfo=tzoffset(None, -18000)),
#  'name': 'uhhpc-lustre-storage',
#  'owner': 'seanbc',
#  'public': False,
#  'revision': 1,
#  'site': None,
#  'status': 'UP',
#  'storage': {'auth': {'type': 'SSHKEYS'},
#   'homeDir': '/',
#   'host': 'uhhpc1.its.hawaii.edu',
#   'mirror': False,
#   'port': 22,
#   'protocol': 'SFTP',
#   'proxy': None,
#   'publicAppsDir': None,
#   'rootDir': '/lus/scratch/seanbc'},
#  'type': 'STORAGE',
#  'uuid': '3456389563291921944-242ac1112-0001-006'}

# %%
system = ag.systems.list(search={'id': 'jgeis-hpc-execution'})[0]

# %%
system.id
# Out:
# u'jgeis-hpc-execution'

# %%
ag.files.list(systemId=system.id,filePath='/')
# Out:
# [{u'_links': {u'history': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/history/system/jgeis-hpc-execution//'},
#    u'metadata': {u'href': u'https://uhhpctenant.its.hawaii.edu/meta/v2/data?q=%7B%22associationIds%22%3A%221968870933610360344-242ac113-0001-002%22%7D'},
#    u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2017, 8, 19, 18, 19, 43, tzinfo=tzoffset(None, -18000)),
#   u'length': 4096,
#   u'mimeType': u'text/directory',
#   u'name': u'.',
#   u'path': u'/',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//.autofsck'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'raw',
#   u'lastModified': datetime.datetime(2018, 4, 12, 20, 33, 30, tzinfo=tzoffset(None, -18000)),
#   u'length': 0,
#   u'mimeType': u'application/octet-stream',
#   u'name': u'.autofsck',
#   u'path': u'/.autofsck',
#   u'permissions': u'READ_WRITE',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'file'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//.autorelabel'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'raw',
#   u'lastModified': datetime.datetime(2014, 10, 2, 21, 21, 55, tzinfo=tzoffset(None, -18000)),
#   u'length': 0,
#   u'mimeType': u'application/octet-stream',
#   u'name': u'.autorelabel',
#   u'path': u'/.autorelabel',
#   u'permissions': u'READ_WRITE',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'file'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//bin'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2018, 4, 4, 16, 5, 21, tzinfo=tzoffset(None, -18000)),
#   u'length': 4096,
#   u'mimeType': u'text/directory',
#   u'name': u'bin',
#   u'path': u'/bin',
#   u'permissions': u'READ_EXECUTE',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//boot'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2018, 4, 12, 20, 29, 35, tzinfo=tzoffset(None, -18000)),
#   u'length': 3072,
#   u'mimeType': u'text/directory',
#   u'name': u'boot',
#   u'path': u'/boot',
#   u'permissions': u'READ_EXECUTE',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//cgroup'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2017, 9, 21, 9, 10, 43, tzinfo=tzoffset(None, -18000)),
#   u'length': 4096,
#   u'mimeType': u'text/directory',
#   u'name': u'cgroup',
#   u'path': u'/cgroup',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//dev'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2018, 4, 12, 20, 34, 19, tzinfo=tzoffset(None, -18000)),
#   u'length': 3880,
#   u'mimeType': u'text/directory',
#   u'name': u'dev',
#   u'path': u'/dev',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//etc'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2018, 4, 12, 22, 37, 53, tzinfo=tzoffset(None, -18000)),
#   u'length': 16384,
#   u'mimeType': u'text/directory',
#   u'name': u'etc',
#   u'path': u'/etc',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//global'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2017, 8, 24, 17, 3, 8, tzinfo=tzoffset(None, -18000)),
#   u'length': 4096,
#   u'mimeType': u'text/directory',
#   u'name': u'global',
#   u'path': u'/global',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//home'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2018, 4, 2, 15, 35, 50, tzinfo=tzoffset(None, -18000)),
#   u'length': 20480,
#   u'mimeType': u'text/directory',
#   u'name': u'home',
#   u'path': u'/home',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//hpc_test_vol'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2017, 7, 28, 13, 16, 47, tzinfo=tzoffset(None, -18000)),
#   u'length': 4096,
#   u'mimeType': u'text/directory',
#   u'name': u'hpc_test_vol',
#   u'path': u'/hpc_test_vol',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//hpc_valuestore'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2017, 7, 21, 18, 31, 12, tzinfo=tzoffset(None, -18000)),
#   u'length': 4096,
#   u'mimeType': u'text/directory',
#   u'name': u'hpc_valuestore',
#   u'path': u'/hpc_valuestore',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//images'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2014, 10, 2, 21, 10, 26, tzinfo=tzoffset(None, -18000)),
#   u'length': 4096,
#   u'mimeType': u'text/directory',
#   u'name': u'images',
#   u'path': u'/images',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//ipathfs'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2018, 4, 12, 20, 33, 45, tzinfo=tzoffset(None, -18000)),
#   u'length': 0,
#   u'mimeType': u'text/directory',
#   u'name': u'ipathfs',
#   u'path': u'/ipathfs',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//itsci'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2015, 8, 28, 16, 23, 8, tzinfo=tzoffset(None, -18000)),
#   u'length': 4096,
#   u'mimeType': u'text/directory',
#   u'name': u'itsci',
#   u'path': u'/itsci',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//lib'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2018, 4, 3, 21, 40, 58, tzinfo=tzoffset(None, -18000)),
#   u'length': 4096,
#   u'mimeType': u'text/directory',
#   u'name': u'lib',
#   u'path': u'/lib',
#   u'permissions': u'READ_EXECUTE',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//lib64'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2018, 4, 12, 22, 37, 52, tzinfo=tzoffset(None, -18000)),
#   u'length': 12288,
#   u'mimeType': u'text/directory',
#   u'name': u'lib64',
#   u'path': u'/lib64',
#   u'permissions': u'READ_EXECUTE',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//lost%2bfound'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2014, 10, 2, 20, 41, 31, tzinfo=tzoffset(None, -18000)),
#   u'length': 16384,
#   u'mimeType': u'text/directory',
#   u'name': u'lost+found',
#   u'path': u'/lost+found',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//lus'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2014, 12, 15, 15, 34, 24, tzinfo=tzoffset(None, -21600)),
#   u'length': 4096,
#   u'mimeType': u'text/directory',
#   u'name': u'lus',
#   u'path': u'/lus',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//MARE2DEMv3.3b.zip'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'raw',
#   u'lastModified': datetime.datetime(2018, 3, 5, 14, 8, 22, tzinfo=tzoffset(None, -21600)),
#   u'length': 5339241,
#   u'mimeType': u'application/octet-stream',
#   u'name': u'MARE2DEMv3.3b.zip',
#   u'path': u'/MARE2DEMv3.3b.zip',
#   u'permissions': u'READ_WRITE',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'file'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//media'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2011, 6, 28, 9, 13, 1, tzinfo=tzoffset(None, -18000)),
#   u'length': 4096,
#   u'mimeType': u'text/directory',
#   u'name': u'media',
#   u'path': u'/media',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//misc'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2017, 10, 15, 20, 0, 21, tzinfo=tzoffset(None, -18000)),
#   u'length': 4096,
#   u'mimeType': u'text/directory',
#   u'name': u'misc',
#   u'path': u'/misc',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//mnt'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2011, 6, 28, 9, 13, 1, tzinfo=tzoffset(None, -18000)),
#   u'length': 4096,
#   u'mimeType': u'text/directory',
#   u'name': u'mnt',
#   u'path': u'/mnt',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//net'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2017, 10, 15, 20, 0, 21, tzinfo=tzoffset(None, -18000)),
#   u'length': 4096,
#   u'mimeType': u'text/directory',
#   u'name': u'net',
#   u'path': u'/net',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//openssl_req.log'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'raw',
#   u'lastModified': datetime.datetime(2014, 12, 11, 13, 43, 7, tzinfo=tzoffset(None, -21600)),
#   u'length': 646,
#   u'mimeType': u'application/octet-stream',
#   u'name': u'openssl_req.log',
#   u'path': u'/openssl_req.log',
#   u'permissions': u'READ_WRITE',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'file'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//opt'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2018, 4, 4, 15, 57, 30, tzinfo=tzoffset(None, -18000)),
#   u'length': 4096,
#   u'mimeType': u'text/directory',
#   u'name': u'opt',
#   u'path': u'/opt',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//proc'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2018, 4, 12, 20, 33, 2, tzinfo=tzoffset(None, -18000)),
#   u'length': 0,
#   u'mimeType': u'text/directory',
#   u'name': u'proc',
#   u'path': u'/proc',
#   u'permissions': u'READ_EXECUTE',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//root'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2018, 4, 12, 19, 12, 2, tzinfo=tzoffset(None, -18000)),
#   u'length': 4096,
#   u'mimeType': u'text/directory',
#   u'name': u'root',
#   u'path': u'/root',
#   u'permissions': u'READ_EXECUTE',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//sbin'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2018, 4, 12, 22, 37, 53, tzinfo=tzoffset(None, -18000)),
#   u'length': 16384,
#   u'mimeType': u'text/directory',
#   u'name': u'sbin',
#   u'path': u'/sbin',
#   u'permissions': u'READ_EXECUTE',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//selinux'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2014, 10, 2, 20, 45, 54, tzinfo=tzoffset(None, -18000)),
#   u'length': 4096,
#   u'mimeType': u'text/directory',
#   u'name': u'selinux',
#   u'path': u'/selinux',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//srv'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2011, 6, 28, 9, 13, 1, tzinfo=tzoffset(None, -18000)),
#   u'length': 4096,
#   u'mimeType': u'text/directory',
#   u'name': u'srv',
#   u'path': u'/srv',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//sys'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2018, 4, 12, 20, 33, 2, tzinfo=tzoffset(None, -18000)),
#   u'length': 0,
#   u'mimeType': u'text/directory',
#   u'name': u'sys',
#   u'path': u'/sys',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//tmp'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2018, 4, 16, 11, 9, tzinfo=tzoffset(None, -18000)),
#   u'length': 2355200,
#   u'mimeType': u'text/directory',
#   u'name': u'tmp',
#   u'path': u'/tmp',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//user_valuestore'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2017, 11, 15, 18, 20, 9, tzinfo=tzoffset(None, -21600)),
#   u'length': 4096,
#   u'mimeType': u'text/directory',
#   u'name': u'user_valuestore',
#   u'path': u'/user_valuestore',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//usr'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2018, 4, 4, 16, 5, 56, tzinfo=tzoffset(None, -18000)),
#   u'length': 4096,
#   u'mimeType': u'text/directory',
#   u'name': u'usr',
#   u'path': u'/usr',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'},
#  {u'_links': {u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/jgeis-hpc-execution//var'},
#    u'system': {u'href': u'https://uhhpctenant.its.hawaii.edu/systems/v2/jgeis-hpc-execution'}},
#   u'format': u'folder',
#   u'lastModified': datetime.datetime(2015, 2, 9, 17, 55, 53, tzinfo=tzoffset(None, -21600)),
#   u'length': 4096,
#   u'mimeType': u'text/directory',
#   u'name': u'var',
#   u'path': u'/var',
#   u'permissions': u'ALL',
#   u'system': u'jgeis-hpc-execution',
#   u'type': u'dir'}]

# %%
#list files on a storage system for a given path
ag.files.list(systemId="uhhpc-lustre-storage",filePath="/")
# Out:
# [{'_links': {'history': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/history/system/uhhpc-lustre-storage//'},
#    'metadata': {'href': 'https://uhhpctenant.its.hawaii.edu/meta/v2/data?q=%7B%22associationIds%22%3A%225967660525505286632-242ac113-0001-002%22%7D'},
#    'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2018, 4, 10, 23, 0, 40, tzinfo=tzoffset(None, -18000)),
#   'length': 12288,
#   'mimeType': 'text/directory',
#   'name': '.',
#   'path': '/',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//50G.dat'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'raw',
#   'lastModified': datetime.datetime(2017, 9, 18, 19, 49, 20, tzinfo=tzoffset(None, -18000)),
#   'length': 50000000000,
#   'mimeType': 'application/octet-stream',
#   'name': '50G.dat',
#   'path': '/50G.dat',
#   'permissions': 'READ_WRITE',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'file'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//82ea7749-4b45-4c88-b232-c4c50ab34fd2.partial'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2015, 3, 10, 18, 57, 40, tzinfo=tzoffset(None, -18000)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': '82ea7749-4b45-4c88-b232-c4c50ab34fd2.partial',
#   'path': '/82ea7749-4b45-4c88-b232-c4c50ab34fd2.partial',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//apps'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2016, 12, 1, 23, 18, 2, tzinfo=tzoffset(None, -21600)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'apps',
#   'path': '/apps',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//bio_workshop'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2017, 9, 11, 23, 56, 17, tzinfo=tzoffset(None, -18000)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'bio_workshop',
#   'path': '/bio_workshop',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//Chang'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2016, 12, 10, 0, 27, 20, tzinfo=tzoffset(None, -21600)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'Chang',
#   'path': '/Chang',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//checkpoint'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2016, 12, 10, 0, 27, 28, tzinfo=tzoffset(None, -21600)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'checkpoint',
#   'path': '/checkpoint',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//cmake-3.2.0-rc2-Linux-x86_64'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2015, 3, 12, 20, 44, 54, tzinfo=tzoffset(None, -18000)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'cmake-3.2.0-rc2-Linux-x86_64',
#   'path': '/cmake-3.2.0-rc2-Linux-x86_64',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//data'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2018, 4, 2, 20, 29, 39, tzinfo=tzoffset(None, -18000)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'data',
#   'path': '/data',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//dc_sampledata_lite'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2017, 4, 5, 15, 12, 5, tzinfo=tzoffset(None, -18000)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'dc_sampledata_lite',
#   'path': '/dc_sampledata_lite',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//dooley'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2016, 1, 26, 16, 14, 48, tzinfo=tzoffset(None, -21600)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'dooley',
#   'path': '/dooley',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//Elliot'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2016, 12, 10, 0, 27, 18, tzinfo=tzoffset(None, -21600)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'Elliot',
#   'path': '/Elliot',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//estacy'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'raw',
#   'lastModified': datetime.datetime(2015, 8, 19, 18, 18, 55, tzinfo=tzoffset(None, -18000)),
#   'length': 19,
#   'mimeType': 'application/octet-stream',
#   'name': 'estacy',
#   'path': '/estacy',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'file'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//ga'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2015, 12, 21, 22, 52, 10, tzinfo=tzoffset(None, -21600)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'ga',
#   'path': '/ga',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//galaxy'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'raw',
#   'lastModified': datetime.datetime(2015, 6, 11, 14, 49, 33, tzinfo=tzoffset(None, -18000)),
#   'length': 43,
#   'mimeType': 'application/octet-stream',
#   'name': 'galaxy',
#   'path': '/galaxy',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'file'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//GeneTorrent-3.8.7'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2015, 12, 21, 22, 26, 17, tzinfo=tzoffset(None, -21600)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'GeneTorrent-3.8.7',
#   'path': '/GeneTorrent-3.8.7',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//gerris'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2016, 12, 10, 0, 27, 21, tzinfo=tzoffset(None, -21600)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'gerris',
#   'path': '/gerris',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//hawaii.edu'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2017, 9, 11, 23, 56, 17, tzinfo=tzoffset(None, -18000)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'hawaii.edu',
#   'path': '/hawaii.edu',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//hgd01_clone'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2016, 12, 10, 0, 27, 21, tzinfo=tzoffset(None, -21600)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'hgd01_clone',
#   'path': '/hgd01_clone',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//Intel-test'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2016, 12, 10, 0, 27, 31, tzinfo=tzoffset(None, -21600)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'Intel-test',
#   'path': '/Intel-test',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//lus'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2015, 3, 11, 19, 40, 49, tzinfo=tzoffset(None, -18000)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'lus',
#   'path': '/lus',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//MARE2DEM'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2018, 3, 15, 15, 32, 41, tzinfo=tzoffset(None, -18000)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'MARE2DEM',
#   'path': '/MARE2DEM',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//MARE2DEM_Source_v3.3b-20180305T192540Z-001.zip'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'raw',
#   'lastModified': datetime.datetime(2018, 3, 5, 13, 34, 3, tzinfo=tzoffset(None, -21600)),
#   'length': 5339241,
#   'mimeType': 'application/octet-stream',
#   'name': 'MARE2DEM_Source_v3.3b-20180305T192540Z-001.zip',
#   'path': '/MARE2DEM_Source_v3.3b-20180305T192540Z-001.zip',
#   'permissions': 'READ_WRITE',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'file'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//MARE2DEMv3.3b.zip'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'raw',
#   'lastModified': datetime.datetime(2018, 3, 5, 14, 8, 22, tzinfo=tzoffset(None, -21600)),
#   'length': 5339241,
#   'mimeType': 'application/octet-stream',
#   'name': 'MARE2DEMv3.3b.zip',
#   'path': '/MARE2DEMv3.3b.zip',
#   'permissions': 'READ_WRITE',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'file'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//migrate-3.6.8'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2015, 12, 21, 22, 16, 20, tzinfo=tzoffset(None, -21600)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'migrate-3.6.8',
#   'path': '/migrate-3.6.8',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//MiSeq_SOP'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2018, 1, 25, 12, 4, 22, tzinfo=tzoffset(None, -21600)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'MiSeq_SOP',
#   'path': '/MiSeq_SOP',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//models'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2018, 3, 29, 12, 39, tzinfo=tzoffset(None, -18000)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'models',
#   'path': '/models',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//mothur_test_files'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2018, 1, 30, 16, 49, 42, tzinfo=tzoffset(None, -21600)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'mothur_test_files',
#   'path': '/mothur_test_files',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//old-bio_workshop'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2017, 9, 11, 23, 56, 34, tzinfo=tzoffset(None, -18000)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'old-bio_workshop',
#   'path': '/old-bio_workshop',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//pv'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2016, 6, 8, 21, 42, 25, tzinfo=tzoffset(None, -18000)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'pv',
#   'path': '/pv',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//pv-1.6.0'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2016, 12, 10, 0, 27, 21, tzinfo=tzoffset(None, -21600)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'pv-1.6.0',
#   'path': '/pv-1.6.0',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//pyrad_example'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2016, 12, 10, 0, 27, 19, tzinfo=tzoffset(None, -21600)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'pyrad_example',
#   'path': '/pyrad_example',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//qiime_overview_tutorial'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2015, 12, 21, 22, 51, 57, tzinfo=tzoffset(None, -21600)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'qiime_overview_tutorial',
#   'path': '/qiime_overview_tutorial',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//R_example'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2016, 12, 10, 0, 27, 19, tzinfo=tzoffset(None, -21600)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'R_example',
#   'path': '/R_example',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//sclevey'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2017, 7, 10, 11, 59, 6, tzinfo=tzoffset(None, -18000)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'sclevey',
#   'path': '/sclevey',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//seanbc'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2018, 4, 16, 20, 52, 8, tzinfo=tzoffset(None, -18000)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'seanbc',
#   'path': '/seanbc',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//singularity'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2018, 4, 11, 0, 0, 29, tzinfo=tzoffset(None, -18000)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'singularity',
#   'path': '/singularity',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//Singularity-tensorflow'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2018, 3, 27, 20, 35, 14, tzinfo=tzoffset(None, -18000)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'Singularity-tensorflow',
#   'path': '/Singularity-tensorflow',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//stacks_test'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2016, 12, 10, 0, 27, 29, tzinfo=tzoffset(None, -21600)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'stacks_test',
#   'path': '/stacks_test',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//tensorflow-gpu.img'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'raw',
#   'lastModified': datetime.datetime(2018, 3, 27, 20, 28, 32, tzinfo=tzoffset(None, -18000)),
#   'length': 1200451615,
#   'mimeType': 'application/octet-stream',
#   'name': 'tensorflow-gpu.img',
#   'path': '/tensorflow-gpu.img',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'file'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//test-parm2'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2015, 12, 21, 22, 26, 16, tzinfo=tzoffset(None, -21600)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'test-parm2',
#   'path': '/test-parm2',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//test-wc'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2016, 12, 10, 0, 27, 18, tzinfo=tzoffset(None, -21600)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'test-wc',
#   'path': '/test-wc',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//tutorial-quickstart'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2016, 12, 10, 0, 27, 22, tzinfo=tzoffset(None, -21600)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'tutorial-quickstart',
#   'path': '/tutorial-quickstart',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//usgsdata'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2018, 1, 4, 16, 11, 35, tzinfo=tzoffset(None, -21600)),
#   'length': 49152,
#   'mimeType': 'text/directory',
#   'name': 'usgsdata',
#   'path': '/usgsdata',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//workflow_test'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2016, 12, 10, 0, 27, 30, tzinfo=tzoffset(None, -21600)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'workflow_test',
#   'path': '/workflow_test',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//wrf'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2018, 3, 20, 21, 22, 24, tzinfo=tzoffset(None, -18000)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'wrf',
#   'path': '/wrf',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'},
#  {'_links': {'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//wrf_install'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2015, 12, 21, 22, 51, 53, tzinfo=tzoffset(None, -21600)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': 'wrf_install',
#   'path': '/wrf_install',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'}]

# %%
#Create directory on storage system
ag.files.manage(body="{'action':'mkdir','path':'test-folders/one'}",systemId="uhhpc-lustre-storage",filePath="/")
# Out:
# {'_links': {'history': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/history/system/uhhpc-lustre-storage//test-folders/one'},
#   'profile': {'href': 'https://uhhpctenant.its.hawaii.edu/profiles/v2/seanbc'},
#   'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//test-folders/one'},
#   'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#  'internalUsername': None,
#  'lastModified': '2018-04-18T02:54:51.352-05:00',
#  'name': 'one',
#  'nativeFormat': 'dir',
#  'owner': 'seanbc',
#  'path': 'test-folders/one',
#  'source': None,
#  'status': 'TRANSFORMING_COMPLETED',
#  'systemId': 'uhhpc-lustre-storage',
#  'uuid': '4173046298764832280-242ac113-0001-002'}

# %%
ag.files.list(systemId="uhhpc-lustre-storage",filePath="/test-folders/one")
# Out:
# [{'_links': {'history': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/history/system/uhhpc-lustre-storage//test-folders/one'},
#    'metadata': {'href': 'https://uhhpctenant.its.hawaii.edu/meta/v2/data?q=%7B%22associationIds%22%3A%224173046298764832280-242ac113-0001-002%22%7D'},
#    'self': {'href': 'https://uhhpctenant.its.hawaii.edu/files/v2/media/system/uhhpc-lustre-storage//test-folders/one'},
#    'system': {'href': 'https://uhhpctenant.its.hawaii.edu/systems/v2/uhhpc-lustre-storage'}},
#   'format': 'folder',
#   'lastModified': datetime.datetime(2018, 4, 18, 2, 56, 3, tzinfo=tzoffset(None, -18000)),
#   'length': 4096,
#   'mimeType': 'text/directory',
#   'name': '.',
#   'path': '/test-folders/one',
#   'permissions': 'ALL',
#   'system': 'uhhpc-lustre-storage',
#   'type': 'dir'}]

# %%
ag.jobs.list()
# Out:
# [{u'_links': {u'archiveData': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/listings/system/uh-hpc-lustre/seanbc/archive/jobs/job-2552339429773611496-242ac114-0001-007'},
#    u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/jobs/v2/2552339429773611496-242ac114-0001-007'}},
#   u'appId': u'uh-hpc-singularity-runner-0.1.0',
#   u'created': u'2018-04-16T20:47:15.000-05:00',
#   u'endTime': datetime.datetime(2018, 4, 16, 20, 50, 57, tzinfo=tzoffset(None, -18000)),
#   u'executionSystem': u'execute.uhhpc1.its.hawaii.edu',
#   u'id': u'2552339429773611496-242ac114-0001-007',
#   u'name': u'conn',
#   u'owner': u'seanbc',
#   u'startTime': datetime.datetime(2018, 4, 16, 20, 47, 42, tzinfo=tzoffset(None, -18000)),
#   u'status': u'FINISHED'},
#  {u'_links': {u'archiveData': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/listings/system/uh-hpc-lustre/seanbc/archive/jobs/job-6798276820021014040-242ac114-0001-007'},
#    u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/jobs/v2/6798276820021014040-242ac114-0001-007'}},
#   u'appId': u'uh-hpc-singularity-runner-0.1.0',
#   u'created': u'2018-04-16T20:42:48.000-05:00',
#   u'endTime': datetime.datetime(2018, 4, 16, 20, 43, 38, tzinfo=tzoffset(None, -18000)),
#   u'executionSystem': u'execute.uhhpc1.its.hawaii.edu',
#   u'id': u'6798276820021014040-242ac114-0001-007',
#   u'name': u'con7',
#   u'owner': u'seanbc',
#   u'startTime': None,
#   u'status': u'FAILED'},
#  {u'_links': {u'archiveData': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/listings/system/uh-hpc-lustre/seanbc/archive/jobs/job-4917605751068561896-242ac114-0001-007'},
#    u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/jobs/v2/4917605751068561896-242ac114-0001-007'}},
#   u'appId': u'uh-hpc-docker-runner-0.1.0',
#   u'created': u'2018-04-16T20:11:33.000-05:00',
#   u'endTime': datetime.datetime(2018, 4, 16, 20, 12, 35, tzinfo=tzoffset(None, -18000)),
#   u'executionSystem': u'execute.uhhpc1.its.hawaii.edu',
#   u'id': u'4917605751068561896-242ac114-0001-007',
#   u'name': u'con6',
#   u'owner': u'seanbc',
#   u'startTime': datetime.datetime(2018, 4, 16, 20, 12, 8, tzinfo=tzoffset(None, -18000)),
#   u'status': u'FINISHED'},
#  {u'_links': {u'archiveData': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/listings/system/uh-hpc-lustre/seanbc/archive/jobs/job-552091864884974056-242ac114-0001-007'},
#    u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/jobs/v2/552091864884974056-242ac114-0001-007'}},
#   u'appId': u'uh-hpc-docker-runner-0.1.0',
#   u'created': u'2018-04-16T19:55:32.000-05:00',
#   u'endTime': datetime.datetime(2018, 4, 16, 19, 56, 10, tzinfo=tzoffset(None, -18000)),
#   u'executionSystem': u'execute.uhhpc1.its.hawaii.edu',
#   u'id': u'552091864884974056-242ac114-0001-007',
#   u'name': u'con2',
#   u'owner': u'seanbc',
#   u'startTime': datetime.datetime(2018, 4, 16, 19, 55, 46, tzinfo=tzoffset(None, -18000)),
#   u'status': u'FINISHED'},
#  {u'_links': {u'archiveData': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/listings/system/uh-hpc-lustre/seanbc/archive/jobs/job-7460706945601180136-242ac114-0001-007'},
#    u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/jobs/v2/7460706945601180136-242ac114-0001-007'}},
#   u'appId': u'uh-hpc-docker-runner-0.1.0',
#   u'created': u'2018-04-16T19:51:25.000-05:00',
#   u'endTime': datetime.datetime(2018, 4, 16, 19, 53, 25, tzinfo=tzoffset(None, -18000)),
#   u'executionSystem': u'execute.uhhpc1.its.hawaii.edu',
#   u'id': u'7460706945601180136-242ac114-0001-007',
#   u'name': u'con1',
#   u'owner': u'seanbc',
#   u'startTime': datetime.datetime(2018, 4, 16, 19, 52, 26, tzinfo=tzoffset(None, -18000)),
#   u'status': u'FINISHED'},
#  {u'_links': {u'archiveData': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/listings/system/uh-hpc-lustre/seanbc/archive/jobs/job-8703242287794679320-242ac114-0001-007'},
#    u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/jobs/v2/8703242287794679320-242ac114-0001-007'}},
#   u'appId': u'uh-hpc-docker-runner-0.1.0',
#   u'created': u'2018-04-16T19:37:38.000-05:00',
#   u'endTime': datetime.datetime(2018, 4, 16, 19, 39, 3, tzinfo=tzoffset(None, -18000)),
#   u'executionSystem': u'execute.uhhpc1.its.hawaii.edu',
#   u'id': u'8703242287794679320-242ac114-0001-007',
#   u'name': u'consss',
#   u'owner': u'seanbc',
#   u'startTime': datetime.datetime(2018, 4, 16, 19, 38, 22, tzinfo=tzoffset(None, -18000)),
#   u'status': u'FINISHED'},
#  {u'_links': {u'archiveData': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/listings/system/uh-hpc-lustre/seanbc/archive/jobs/job-626531757022712296-242ac114-0001-007'},
#    u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/jobs/v2/626531757022712296-242ac114-0001-007'}},
#   u'appId': u'uh-hpc-docker-runner-0.1.0',
#   u'created': u'2018-04-16T19:34:05.000-05:00',
#   u'endTime': datetime.datetime(2018, 4, 16, 19, 34, 50, tzinfo=tzoffset(None, -18000)),
#   u'executionSystem': u'execute.uhhpc1.its.hawaii.edu',
#   u'id': u'626531757022712296-242ac114-0001-007',
#   u'name': u'conss',
#   u'owner': u'seanbc',
#   u'startTime': datetime.datetime(2018, 4, 16, 19, 34, 27, tzinfo=tzoffset(None, -18000)),
#   u'status': u'FINISHED'},
#  {u'_links': {u'archiveData': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/listings/system/uh-hpc-lustre/seanbc/archive/jobs/job-5955763322135113240-242ac114-0001-007'},
#    u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/jobs/v2/5955763322135113240-242ac114-0001-007'}},
#   u'appId': u'uh-hpc-docker-runner-0.1.0',
#   u'created': u'2018-04-16T19:31:32.000-05:00',
#   u'endTime': datetime.datetime(2018, 4, 16, 19, 32, 40, tzinfo=tzoffset(None, -18000)),
#   u'executionSystem': u'execute.uhhpc1.its.hawaii.edu',
#   u'id': u'5955763322135113240-242ac114-0001-007',
#   u'name': u'cons',
#   u'owner': u'seanbc',
#   u'startTime': datetime.datetime(2018, 4, 16, 19, 32, 12, tzinfo=tzoffset(None, -18000)),
#   u'status': u'FINISHED'},
#  {u'_links': {u'archiveData': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/listings/system/uh-hpc-lustre/seanbc/archive/jobs/job-4559894142780838376-242ac114-0001-007'},
#    u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/jobs/v2/4559894142780838376-242ac114-0001-007'}},
#   u'appId': u'uh-hpc-docker-runner-0.1.0',
#   u'created': u'2018-04-16T19:28:27.000-05:00',
#   u'endTime': datetime.datetime(2018, 4, 16, 19, 29, 15, tzinfo=tzoffset(None, -18000)),
#   u'executionSystem': u'execute.uhhpc1.its.hawaii.edu',
#   u'id': u'4559894142780838376-242ac114-0001-007',
#   u'name': u'con',
#   u'owner': u'seanbc',
#   u'startTime': datetime.datetime(2018, 4, 16, 19, 29, 8, tzinfo=tzoffset(None, -18000)),
#   u'status': u'FINISHED'},
#  {u'_links': {u'archiveData': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/listings/system/uh-hpc-lustre/seanbc/archive/jobs/job-392117250161307160-242ac114-0001-007'},
#    u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/jobs/v2/392117250161307160-242ac114-0001-007'}},
#   u'appId': u'uh-hpc-docker-runner-0.1.0',
#   u'created': u'2018-04-16T19:26:32.000-05:00',
#   u'endTime': datetime.datetime(2018, 4, 16, 19, 27, tzinfo=tzoffset(None, -18000)),
#   u'executionSystem': u'execute.uhhpc1.its.hawaii.edu',
#   u'id': u'392117250161307160-242ac114-0001-007',
#   u'name': u'container-test5',
#   u'owner': u'seanbc',
#   u'startTime': datetime.datetime(2018, 4, 16, 19, 26, 54, tzinfo=tzoffset(None, -18000)),
#   u'status': u'FINISHED'},
#  {u'_links': {u'archiveData': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/listings/system/uh-hpc-lustre/seanbc/archive/jobs/job-7194142856182427160-242ac114-0001-007'},
#    u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/jobs/v2/7194142856182427160-242ac114-0001-007'}},
#   u'appId': u'uh-hpc-docker-runner-0.1.0',
#   u'created': u'2018-04-16T19:23:54.000-05:00',
#   u'endTime': datetime.datetime(2018, 4, 16, 19, 24, 30, tzinfo=tzoffset(None, -18000)),
#   u'executionSystem': u'execute.uhhpc1.its.hawaii.edu',
#   u'id': u'7194142856182427160-242ac114-0001-007',
#   u'name': u'container-test4',
#   u'owner': u'seanbc',
#   u'startTime': datetime.datetime(2018, 4, 16, 19, 24, 27, tzinfo=tzoffset(None, -18000)),
#   u'status': u'FINISHED'},
#  {u'_links': {u'archiveData': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/listings/system/uh-hpc-lustre/seanbc/archive/jobs/job-4884578756023021080-242ac114-0001-007'},
#    u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/jobs/v2/4884578756023021080-242ac114-0001-007'}},
#   u'appId': u'uh-hpc-docker-runner-0.1.0',
#   u'created': u'2018-04-16T19:17:38.000-05:00',
#   u'endTime': datetime.datetime(2018, 4, 16, 19, 18, tzinfo=tzoffset(None, -18000)),
#   u'executionSystem': u'execute.uhhpc1.its.hawaii.edu',
#   u'id': u'4884578756023021080-242ac114-0001-007',
#   u'name': u'container-test3',
#   u'owner': u'seanbc',
#   u'startTime': datetime.datetime(2018, 4, 16, 19, 17, 56, tzinfo=tzoffset(None, -18000)),
#   u'status': u'FINISHED'},
#  {u'_links': {u'archiveData': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/listings/system/uh-hpc-lustre/seanbc/archive/jobs/job-7150357416946495000-242ac114-0001-007'},
#    u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/jobs/v2/7150357416946495000-242ac114-0001-007'}},
#   u'appId': u'uh-hpc-docker-runner-0.1.0',
#   u'created': u'2018-04-16T19:09:36.000-05:00',
#   u'endTime': datetime.datetime(2018, 4, 16, 19, 10, tzinfo=tzoffset(None, -18000)),
#   u'executionSystem': u'execute.uhhpc1.its.hawaii.edu',
#   u'id': u'7150357416946495000-242ac114-0001-007',
#   u'name': u'container-test2',
#   u'owner': u'seanbc',
#   u'startTime': datetime.datetime(2018, 4, 16, 19, 9, 57, tzinfo=tzoffset(None, -18000)),
#   u'status': u'FINISHED'},
#  {u'_links': {u'archiveData': {u'href': u'https://uhhpctenant.its.hawaii.edu/files/v2/listings/system/uh-hpc-lustre/seanbc/archive/jobs/job-5383399762474036760-242ac114-0001-007'},
#    u'self': {u'href': u'https://uhhpctenant.its.hawaii.edu/jobs/v2/5383399762474036760-242ac114-0001-007'}},
#   u'appId': u'uh-hpc-docker-runner-0.1.0',
#   u'created': u'2018-04-16T18:48:48.000-05:00',
#   u'endTime': datetime.datetime(2018, 4, 16, 18, 49, 10, tzinfo=tzoffset(None, -18000)),
#   u'executionSystem': u'execute.uhhpc1.its.hawaii.edu',
#   u'id': u'5383399762474036760-242ac114-0001-007',
#   u'name': u'container-test1',
#   u'owner': u'seanbc',
#   u'startTime': datetime.datetime(2018, 4, 16, 18, 49, 6, tzinfo=tzoffset(None, -18000)),
#   u'status': u'FINISHED'}]

# %%
ag.restore()
